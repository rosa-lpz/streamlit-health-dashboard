# %% [markdown]
# # WHO Global Health Observatory Data Exploration
#
# This notebook explores health data from the WHO GHO OData API for Sustainable Development Goals (SDGs).

# %%
# Import Required Libraries
import pandas as pd
import requests
import plotly.express as px
import plotly.graph_objects as go

# WHO GHO API Base URL
API_BASE_URL = "https://ghoapi.azureedge.net/api"

print("Libraries loaded successfully!")
# Out:
# Libraries loaded successfully!

# %% [markdown]
# ## 1. Fetch Available Dimensions
#
# Let's see what dimensions are available in the WHO API.

# %%
# Fetch available dimensions
response = requests.get(f"{API_BASE_URL}/Dimension")
dimensions = pd.DataFrame(response.json()["value"])
print(f"Available Dimensions: {len(dimensions)}")
dimensions
# Out:
# Available Dimensions: 192
#                    Code                                    Title
# 0       ADVERTISINGTYPE        SUBSTANCE_ABUSE_ADVERTISING_TYPES
# 1              AGEGROUP                                Age Group
# 2           ALCOHOLTYPE                           Beverage Types
# 3      AMRGLASSCATEGORY                       AMR GLASS Category
# 4            ANTIBIOTIC                               Antibiotic
# ..                  ...                                      ...
# 187      WPR_DATASOURCE                         WPRO Data Source
# 188        WPR_DEMO_IND                      WPRO Demo Indicator
# 189  WRS_OUTSIDE_REPORT  WRs from outside the region year report
# 190          WRS_STATUS                WHO Representative Status
# 191                YEAR                                     Year
#
# [192 rows x 2 columns]

# %% [markdown]
# ## 2. Fetch Countries List
#
# Get the list of all countries available in the dataset.

# %%
# Fetch countries
response = requests.get(f"{API_BASE_URL}/DIMENSION/COUNTRY/DimensionValues")
countries = pd.DataFrame(response.json()["value"])
print(f"Total Countries: {len(countries)}")
countries[["Code", "Title"]].head(20)
# Out:
# Total Countries: 234
#    Code                              Title
# 0   ABW                              Aruba
# 1   AFG                        Afghanistan
# 2   AGO                             Angola
# 3   AIA                           Anguilla
# 4   ALB                            Albania
# 5   AND                            Andorra
# 6   ARE               United Arab Emirates
# 7   ARG                          Argentina
# 8   ARM                            Armenia
# 9   ASM                     American Samoa
# 10  ATG                Antigua and Barbuda
# 11  AUS                          Australia
# 12  AUT                            Austria
# 13  AZE                         Azerbaijan
# 14  BDI                            Burundi
# 15  BEL                            Belgium
# 16  BEN                              Benin
# 17  BES  Bonaire, Saint Eustatius and Saba
# 18  BFA                       Burkina Faso
# 19  BGD                         Bangladesh

# %% [markdown]
# ## 3. Fetch WHO Regions

# %%
# Fetch WHO regions
response = requests.get(f"{API_BASE_URL}/DIMENSION/REGION/DimensionValues")
regions = pd.DataFrame(response.json()["value"])
print(f"WHO Regions: {len(regions)}")
regions[["Code", "Title"]]
# Out:
# WHO Regions: 43
#                Code                                              Title
# 0               AFR                                             Africa
# 1               AMR                                           Americas
# 2               EMR                              Eastern Mediterranean
# 3               EUR                                             Europe
# 4    GBD_REG14_AFRD                   Africa region, stratum D (AFR D)
# 5    GBD_REG14_AFRE                    Africa region, stratum E(AFR E)
# 6    GBD_REG14_AMRA                 Americas region, stratum A (AMR A)
# 7    GBD_REG14_AMRB                 Americas region, stratum B (AMR B)
# 8    GBD_REG14_AMRD                 Americas region, stratum D (AMR D)
# 9    GBD_REG14_EMRB    Eastern Mediterranean region, stratum B (EMR B)
# 10   GBD_REG14_EMRD    Eastern Mediterranean region, stratum D (EMR D)
# 11   GBD_REG14_EURA                   Europe region, stratum A (EUR A)
# 12   GBD_REG14_EURB                   Europe region, stratum B (EUR B)
# 13   GBD_REG14_EURC                   Europe region, stratum C (EUR C)
# 14  GBD_REG14_SEARB         South East Asia region, stratum B (SEAR B)
# 15  GBD_REG14_SEARD         South East Asia region, stratum D (SEAR D)
# 16   GBD_REG14_WPRA          Western Pacific region, stratum A (WPR A)
# 17   GBD_REG14_WPRB          Western Pacific region, stratum B (WPR B)
# 18               NC                                     Not classified
# 19          NOTSPEC                                      Not specified
# 20     OECD_HII_AMR                         Americas, high-income OECD
# 21     OECD_HII_EUR                           Europe, high-income OECD
# 22     OECD_HII_WPR                 Western Pacific , high-income OECD
# 23     OECD_NON_AFR                                  Africa (non-OECD)
# 24     OECD_NON_AMR                                 Americas, non-OECD
# 25     OECD_NON_EMR                   Eastern Mediterranean (non-OECD)
# 26     OECD_NON_EUR                                   Europe, non-OECD
# 27    OECD_NON_SEAR                         South-East Asia (non-OECD)
# 28     OECD_NON_WPR                          Western Pacific, non-OECD
# 29             SEAR                                    South-East Asia
# 30       SEAR_W_IDN                     South-East Asia with Indonesia
# 31    WHO_HI_GLOBAL             WHO High income countries of the world
# 32      WHO_LMI_AFR  Low-and-middle-income countries of the African...
# 33      WHO_LMI_AMR    Low-and-middle-income countries of the Americas
# 34      WHO_LMI_EMR  Low-and-middle-income countries of the Eastern...
# 35      WHO_LMI_EUR  Low-and-middle-income countries of the Europea...
# 36      WHO_LMI_HIC                              High income countries
# 37     WHO_LMI_SEAR  Low-and-middle-income countries of the South-E...
# 38    WHO_LMI_WORLD                                   Global (WHO LMI)
# 39      WHO_LMI_WPR  Low-and-middle-income countries of the Western...
# 40       WHO_NONMEM                                    WHO Non Members
# 41              WPR                                    Western Pacific
# 42       WPR_WO_IDN                  Western Pacific without Indonesia

# %% [markdown]
# ## 4. Search for SDG Health Indicators
#
# Let's search for indicators related to Sustainable Development Goals.

# %%
# Fetch all indicators (limited)
response = requests.get(f"{API_BASE_URL}/Indicator")
all_indicators = pd.DataFrame(response.json()["value"])
print(f"Total Indicators: {len(all_indicators)}")
all_indicators[["IndicatorCode", "IndicatorName"]].head(20)
# Out:
# Total Indicators: 3055
#                             IndicatorCode  \
# 0                 EMFLIMITPOWERDENSITY900
# 1                       EMFPOWERFREQUENCY
# 2   FINPROTECTION_CATA_ESTIMATE_AVAILABLE
# 3      FINPROTECTION_CATA_TOT_25_LEVEL_SH
# 4       FINPROTECTION_IMP_NP_190_LEVEL_SH
# 5                          HIV_0000000009
# 6                                GOE_Q203
# 7                     HCF_REL_ELECTRICITY
# 8                          HIV_0000000007
# 9                          HIV_0000000008
# 10                                 HRH_05
# 11                                 HRH_16
# 12                                 HRH_17
# 13                                 HRH_20
# 14                                 HRH_21
# 15                                 HRH_22
# 16                                 HRH_23
# 17                         HIV_0000000015
# 18                         HIV_0000000016
# 19                         HIV_0000000022
#
#                                         IndicatorName
# 0              Power density limit at 900 MHz (W/m^2)
# 1                                Power frequency (Hz)
# 2   Availability of estimates on large  health exp...
# 3   Population with household spending on health g...
# 4   Total population  pushed below the $1.90 a day...
# 5   Reported number of people receiving antiretrov...
# 6   Lack of integration between various health ser...
# 7   Percentage of health-care facilities with reli...
# 8   Testing and counselling facilities, reported n...
# 9   Testing and counselling facilities, estimated ...
# 10    Number of pharmaceutical technicians/assistants
# 11       Number of traditional medicine practitioners
# 12                       Number of medical assistants
# 13                Number of laboratory health workers
# 14                      Number of dentistry personnel
# 15  Number of community and traditional health wor...
# 16                     Number of other health workers
# 17  Number of pregnant women living with HIV who r...
# 18  Number of pregnant women living with HIV who r...
# 19  Estimated number of people eligible for antire...

# %%
# Search for SDG-related indicators
sdg_indicators = all_indicators[all_indicators["IndicatorName"].str.contains("SDG|mortality|life expectancy", case=False, na=False)]
print(f"SDG-related Indicators: {len(sdg_indicators)}")
sdg_indicators[["IndicatorCode", "IndicatorName"]].head(30)
# Out:
# SDG-related Indicators: 49
#                                 IndicatorCode  \
# 3          FINPROTECTION_CATA_TOT_25_LEVEL_SH
# 38    FINPROTECTION_CATA_TOT_10_LEVEL_MILLION
# 39         FINPROTECTION_CATA_TOT_10_LEVEL_SH
# 40              FINPROTECTION_CATA_TOT_10_POP
# 41    FINPROTECTION_CATA_TOT_25_LEVEL_MILLION
# 44              FINPROTECTION_CATA_TOT_25_POP
# 214                                       imr
# 295                                   MORTADO
# 310                            MDG_0000000007
# 317                            MDG_0000000001
# 387                            MDG_0000000032
# 428                            MDG_0000000026
# 464                            CHILDMORT5TO14
# 747                                       nmr
# 957                             SA_0000001473
# 994                             SA_0000001472
# 1106                                SDGPOISON
# 1107                               SDGROADAGE
# 1123                                SDGWSHBOD
# 1377                            SA_0000001688
# 1577                                     u5mr
# 1578                   UHC_AVAILABILITY_SCORE
# 1584                                 WHS2_131
# 1586                                 WHS2_160
# 1601                                    WSH_1
# 1623                                 WHS2_161
# 1648                       UHC_INDEX_REPORTED
# 1853                            WHOSIS_000007
# 1857                            WHOSIS_000015
# 1860                            WHOSIS_000002
#
#                                           IndicatorName
# 3     Population with household spending on health g...
# 38    Population with household spending on health g...
# 39    Population with household spending on health g...
# 40    Population with household spending on health g...
# 41    Population with household spending on health g...
# 44    Population with household spending on health g...
# 214   Infant mortality rate (deaths per 1000 live bi...
# 295   Adolescent mortality rate (per 1 000 age speci...
# 310   Under-five mortality rate (probability of dyin...
# 317   Infant mortality rate (probability of dying be...
# 387   Maternal mortality ratio (per 100 000 live bir...
# 428   Maternal mortality ratio (per 100 000 live bir...
# 464   Mortality rate for 5-14 year-olds (probability...
# 747   Neonatal mortality rate (deaths per 1000 live ...
# 957   Alcohol-related disease mortality, per 100,000...
# 994         Alcohol-related injury mortality, per 1,000
# 1106  Mortality rate attributed to unintentional poi...
# 1107  Age-standardized road traffic  mortality (per ...
# 1123  Mortality rate attributed to exposure to unsaf...
# 1377  Alcohol, total per capita (15+) consumption (i...
# 1577  Under-five mortality rate (deaths per 1000 liv...
# 1578  Primary data availability for UHC Service Cove...
# 1584  Age-standardized NCD mortality rate  (per 100 ...
# 1586  Age-standardized mortality rate by cause (per ...
# 1601                              SDG 3.9.2 WASH deaths
# 1623  Age-standardized mortality rate by cause (per ...
# 1648             UHC Service Coverage Index (SDG 3.8.1)
# 1853   Healthy life expectancy (HALE) at age 60 (years)
# 1857                  Life expectancy at age 60 (years)
# 1860    Healthy life expectancy (HALE) at birth (years)

# %% [markdown]
# ## 5. Fetch Life Expectancy Data
#
# Let's fetch and explore Life Expectancy at Birth data.

# %%
# Fetch Life Expectancy data
indicator_code = "WHOSIS_000001"  # Life expectancy at birth
response = requests.get(f"{API_BASE_URL}/{indicator_code}")
life_expectancy = pd.DataFrame(response.json()["value"])

print(f"Records: {len(life_expectancy)}")
print(f"\nColumns: {life_expectancy.columns.tolist()}")
life_expectancy.head(10)
# Out:
# Records: 12936
#
# Columns: ['Id', 'IndicatorCode', 'SpatialDimType', 'SpatialDim', 'ParentLocationCode', 'TimeDimType', 'ParentLocation', 'Dim1Type', 'TimeDim', 'Dim1', 'Dim2Type', 'Dim2', 'Dim3Type', 'Dim3', 'DataSourceDimType', 'DataSourceDim', 'Value', 'NumericValue', 'Low', 'High', 'Comments', 'Date', 'TimeDimensionValue', 'TimeDimensionBegin', 'TimeDimensionEnd']
#         Id  IndicatorCode        SpatialDimType SpatialDim ParentLocationCode  \
# 0  9768193  WHOSIS_000001               COUNTRY        TJK                EUR
# 1  9768267  WHOSIS_000001  WORLDBANKINCOMEGROUP     WB_LMI               None
# 2  9768536  WHOSIS_000001               COUNTRY        BLZ                AMR
# 3  9769054  WHOSIS_000001               COUNTRY        CRI                AMR
# 4  9769581  WHOSIS_000001               COUNTRY        PNG                WPR
# 5  9771412  WHOSIS_000001               COUNTRY        MDA                EUR
# 6  9772444  WHOSIS_000001               COUNTRY        LUX                EUR
# 7  9773020  WHOSIS_000001               COUNTRY        SVK                EUR
# 8  9773516  WHOSIS_000001               COUNTRY        BHR                EMR
# 9  9773569  WHOSIS_000001               COUNTRY        CHN                WPR
#
#   TimeDimType         ParentLocation Dim1Type  TimeDim      Dim1  ...  \
# 0        YEAR                 Europe      SEX     2009  SEX_BTSX  ...
# 1        YEAR                   None      SEX     2014  SEX_BTSX  ...
# 2        YEAR               Americas      SEX     2009  SEX_BTSX  ...
# 3        YEAR               Americas      SEX     2019  SEX_BTSX  ...
# 4        YEAR        Western Pacific      SEX     2009   SEX_MLE  ...
# 5        YEAR                 Europe      SEX     2011  SEX_BTSX  ...
# 6        YEAR                 Europe      SEX     2005  SEX_FMLE  ...
# 7        YEAR                 Europe      SEX     2005   SEX_MLE  ...
# 8        YEAR  Eastern Mediterranean      SEX     2020  SEX_FMLE  ...
# 9        YEAR        Western Pacific      SEX     2000  SEX_FMLE  ...
#
#   DataSourceDim             Value NumericValue        Low       High Comments  \
# 0          None  69.3 [68.8-69.9]    69.345311  68.838784  69.886027     None
# 1          None  68.0 [67.5-68.6]    68.039758  67.486191  68.608364     None
# 2          None  73.7 [73.5-73.9]    73.670099  73.477567  73.919821     None
# 3          None  80.3 [80.2-80.4]    80.300732  80.204039  80.423448     None
# 4          None  63.8 [63.1-64.7]    63.817352  63.127693  64.671811     None
# 5          None  69.8 [69.6-70.0]    69.820704  69.642998  70.030446     None
# 6          None  82.1 [82.0-82.2]    82.073297  82.007442  82.235889     None
# 7          None  70.2 [70.1-70.3]    70.187024  70.128752  70.315256     None
# 8          None  76.8 [76.5-77.1]    76.769973  76.513988  77.059442     None
# 9          None  73.3 [73.0-73.8]    73.333632  73.007768  73.767402     None
#
#                             Date  TimeDimensionValue  \
# 0  2024-08-02T09:43:39.193+02:00                2009
# 1  2024-08-02T09:43:39.193+02:00                2014
# 2  2024-08-02T09:43:39.193+02:00                2009
# 3  2024-08-02T09:43:39.193+02:00                2019
# 4  2024-08-02T09:43:39.193+02:00                2009
# 5  2024-08-02T09:43:39.193+02:00                2011
# 6  2024-08-02T09:43:39.193+02:00                2005
# 7  2024-08-02T09:43:39.193+02:00                2005
# 8  2024-08-02T09:43:39.193+02:00                2020
# 9  2024-08-02T09:43:39.193+02:00                2000
#
#           TimeDimensionBegin           TimeDimensionEnd
# 0  2009-01-01T00:00:00+01:00  2009-12-31T00:00:00+01:00
# 1  2014-01-01T00:00:00+01:00  2014-12-31T00:00:00+01:00
# 2  2009-01-01T00:00:00+01:00  2009-12-31T00:00:00+01:00
# 3  2019-01-01T00:00:00+01:00  2019-12-31T00:00:00+01:00
# 4  2009-01-01T00:00:00+01:00  2009-12-31T00:00:00+01:00
# 5  2011-01-01T00:00:00+01:00  2011-12-31T00:00:00+01:00
# 6  2005-01-01T00:00:00+01:00  2005-12-31T00:00:00+01:00
# 7  2005-01-01T00:00:00+01:00  2005-12-31T00:00:00+01:00
# 8  2020-01-01T00:00:00+01:00  2020-12-31T00:00:00+01:00
# 9  2000-01-01T00:00:00+01:00  2000-12-31T00:00:00+01:00
#
# [10 rows x 25 columns]

# %%
# Clean and process the data
life_exp_clean = life_expectancy[["SpatialDim", "TimeDim", "Dim1", "NumericValue"]].copy()
life_exp_clean.columns = ["Country", "Year", "Sex", "LifeExpectancy"]
life_exp_clean["Year"] = pd.to_numeric(life_exp_clean["Year"], errors="coerce")
life_exp_clean["LifeExpectancy"] = pd.to_numeric(life_exp_clean["LifeExpectancy"], errors="coerce")
life_exp_clean = life_exp_clean.dropna()

print(f"Cleaned Records: {len(life_exp_clean)}")
print(f"Year Range: {life_exp_clean['Year'].min():.0f} - {life_exp_clean['Year'].max():.0f}")
print(f"Countries: {life_exp_clean['Country'].nunique()}")
life_exp_clean.head(10)
# Out:
# Cleaned Records: 12936
# Year Range: 2000 - 2021
# Countries: 196
#   Country  Year       Sex  LifeExpectancy
# 0     TJK  2009  SEX_BTSX       69.345311
# 1  WB_LMI  2014  SEX_BTSX       68.039758
# 2     BLZ  2009  SEX_BTSX       73.670099
# 3     CRI  2019  SEX_BTSX       80.300732
# 4     PNG  2009   SEX_MLE       63.817352
# 5     MDA  2011  SEX_BTSX       69.820704
# 6     LUX  2005  SEX_FMLE       82.073297
# 7     SVK  2005   SEX_MLE       70.187024
# 8     BHR  2020  SEX_FMLE       76.769973
# 9     CHN  2000  SEX_FMLE       73.333632

# %%
# Visualize Life Expectancy by Year (Global Average)
global_avg = life_exp_clean.groupby(["Year", "Sex"])["LifeExpectancy"].mean().reset_index()

fig = px.line(global_avg, x="Year", y="LifeExpectancy", color="Sex",
              title="Global Average Life Expectancy at Birth by Sex",
              labels={"LifeExpectancy": "Life Expectancy (years)"})
fig.update_layout(template="plotly_white")
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 8
#       4 fig = px.line(global_avg, x="Year", y="LifeExpectancy", color="Sex",
#       5               title="Global Average Life Expectancy at Birth by Sex",
#       6               labels={"LifeExpectancy": "Life Expectancy (years)"})
#       7 fig.update_layout(template="plotly_white")
# ----> 8 fig.show()
#
# File ~/Documents/GitHub/portfolio-projects/streamlit-health-dashboard/envenv/lib/python3.11/site-packages/plotly/basedatatypes.py:3420, in BaseFigure.show(self, *args, **kwargs)
#    3387 """
#    3388 Show a figure using either the default renderer(s) or the renderer(s)
#    3389 specified by the renderer argument
#    (...)   3416 None
#    3417 """
#    3418 import plotly.io as pio
# -> 3420 return pio.show(self, *args, **kwargs)
#
# File ~/Documents/GitHub/portfolio-projects/streamlit-health-dashboard/envenv/lib/python3.11/site-packages/plotly/io/_renderers.py:415, in show(fig, renderer, validate, **kwargs)
#     410     raise ValueError(
#     411         "Mime type rendering requires ipython but it is not installed"
#     412     )
#     414 if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 415     raise ValueError(
#     416         "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     417     )
#     419 display_jupyter_version_warnings()
#     421 ipython_display.display(bundle, raw=True)
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed

# %% [markdown]
# ## 6. Fetch Maternal Mortality Data (SDG 3.1)

# %%
# Fetch Maternal Mortality data
indicator_code = "MDG_0000000001"  # Maternal mortality ratio
response = requests.get(f"{API_BASE_URL}/{indicator_code}")
maternal_mortality = pd.DataFrame(response.json()["value"])

print(f"Maternal Mortality Records: {len(maternal_mortality)}")
maternal_mortality.head()
# Out:
# Maternal Mortality Records: 43513
#         Id   IndicatorCode SpatialDimType    SpatialDim ParentLocationCode  \
# 0  9768968  MDG_0000000001        COUNTRY           AZE                EUR
# 1  9768988  MDG_0000000001        COUNTRY           SWE                EUR
# 2  9769157  MDG_0000000001        MGHEREG  UNICEF_LACRO               None
# 3  9769329  MDG_0000000001        COUNTRY           DMA                AMR
# 4  9769480  MDG_0000000001        COUNTRY           ATG                AMR
#
#   TimeDimType ParentLocation Dim1Type      Dim1  TimeDim  ... DataSourceDim  \
# 0        YEAR         Europe      SEX   SEX_MLE     2009  ...          None
# 1        YEAR         Europe      SEX  SEX_FMLE     1983  ...          None
# 2        YEAR           None      SEX  SEX_BTSX     2013  ...          None
# 3        YEAR       Americas      SEX   SEX_MLE     2015  ...          None
# 4        YEAR       Americas      SEX  SEX_BTSX     1999  ...          None
#
#               Value NumericValue        Low       High Comments  \
# 0  33.7 [28.0-40.5]    33.710192  27.979396  40.470787     None
# 1     5.9 [5.7-6.1]     5.936449   5.731761   6.147711     None
# 2  16.3 [16.0-16.8]    16.309493  15.959494  16.780849     None
# 3  28.4 [25.7-31.3]    28.378631  25.694694  31.265511     None
# 4  12.4 [11.1-13.9]    12.415650  11.149507  13.856991     None
#
#                             Date  TimeDimensionValue  \
# 0  2025-04-15T15:49:27.583+02:00                2009
# 1  2025-04-15T15:49:27.583+02:00                1983
# 2  2025-04-15T15:49:27.583+02:00                2013
# 3  2025-04-15T15:49:27.583+02:00                2015
# 4  2025-04-15T15:49:27.583+02:00                1999
#
#           TimeDimensionBegin           TimeDimensionEnd
# 0  2009-01-01T00:00:00+01:00  2009-12-31T00:00:00+01:00
# 1  1983-01-01T00:00:00+01:00  1983-12-31T00:00:00+01:00
# 2  2013-01-01T00:00:00+01:00  2013-12-31T00:00:00+01:00
# 3  2015-01-01T00:00:00+01:00  2015-12-31T00:00:00+01:00
# 4  1999-01-01T00:00:00+01:00  1999-12-31T00:00:00+01:00
#
# [5 rows x 25 columns]

# %%
# Process maternal mortality data
mm_clean = maternal_mortality[["SpatialDim", "TimeDim", "NumericValue"]].copy()
mm_clean.columns = ["Country", "Year", "MaternalMortalityRatio"]
mm_clean["Year"] = pd.to_numeric(mm_clean["Year"], errors="coerce")
mm_clean["MaternalMortalityRatio"] = pd.to_numeric(mm_clean["MaternalMortalityRatio"], errors="coerce")
mm_clean = mm_clean.dropna()

# Get latest year data
latest_year = mm_clean["Year"].max()
mm_latest = mm_clean[mm_clean["Year"] == latest_year].sort_values("MaternalMortalityRatio", ascending=False)

print(f"Latest Year: {latest_year:.0f}")
print(f"\nTop 10 Countries with Highest Maternal Mortality:")
mm_latest.head(10)

# %%
# Visualize Maternal Mortality on World Map
fig = px.choropleth(mm_latest, 
                    locations="Country",
                    color="MaternalMortalityRatio",
                    hover_name="Country",
                    color_continuous_scale="Reds",
                    title=f"Maternal Mortality Ratio per 100,000 Live Births ({latest_year:.0f})")
fig.update_layout(geo=dict(showframe=False, projection_type="natural earth"))
fig.show()

# %% [markdown]
# ## 7. Fetch Under-5 Mortality Data (SDG 3.2)

# %%
# Fetch Under-5 Mortality data
indicator_code = "MDG_0000000007"  # Under-five mortality rate
response = requests.get(f"{API_BASE_URL}/{indicator_code}")
under5_mortality = pd.DataFrame(response.json()["value"])

# Process data
u5_clean = under5_mortality[["SpatialDim", "TimeDim", "NumericValue"]].copy()
u5_clean.columns = ["Country", "Year", "Under5MortalityRate"]
u5_clean["Year"] = pd.to_numeric(u5_clean["Year"], errors="coerce")
u5_clean["Under5MortalityRate"] = pd.to_numeric(u5_clean["Under5MortalityRate"], errors="coerce")
u5_clean = u5_clean.dropna()

print(f"Under-5 Mortality Records: {len(u5_clean)}")
u5_clean.head(10)

# %%
# Global trend of Under-5 Mortality
u5_trend = u5_clean.groupby("Year")["Under5MortalityRate"].mean().reset_index()

fig = px.line(u5_trend, x="Year", y="Under5MortalityRate",
              title="Global Average Under-5 Mortality Rate (per 1,000 live births)",
              markers=True)
fig.update_layout(template="plotly_white")
fig.show()

# %% [markdown]
# ## 8. Fetch UHC Service Coverage Index (SDG 3.8)

# %%
# Fetch UHC Service Coverage data
indicator_code = "UHC_INDEX_REPORTED"  # UHC service coverage index
response = requests.get(f"{API_BASE_URL}/{indicator_code}")
uhc_data = pd.DataFrame(response.json()["value"])

# Process data
uhc_clean = uhc_data[["SpatialDim", "TimeDim", "NumericValue"]].copy()
uhc_clean.columns = ["Country", "Year", "UHC_Index"]
uhc_clean["Year"] = pd.to_numeric(uhc_clean["Year"], errors="coerce")
uhc_clean["UHC_Index"] = pd.to_numeric(uhc_clean["UHC_Index"], errors="coerce")
uhc_clean = uhc_clean.dropna()

print(f"UHC Index Records: {len(uhc_clean)}")
uhc_clean.describe()

# %%
# Distribution of UHC Index (latest year)
latest_year = uhc_clean["Year"].max()
uhc_latest = uhc_clean[uhc_clean["Year"] == latest_year]

fig = px.histogram(uhc_latest, x="UHC_Index", nbins=30,
                   title=f"Distribution of UHC Service Coverage Index ({latest_year:.0f})",
                   labels={"UHC_Index": "UHC Index (0-100)"})
fig.update_layout(template="plotly_white")
fig.show()

# %% [markdown]
# ## 9. Summary Statistics

# %%
# Create a summary of all fetched data
summary = {
    "Dataset": ["Life Expectancy", "Maternal Mortality", "Under-5 Mortality", "UHC Index"],
    "Records": [len(life_exp_clean), len(mm_clean), len(u5_clean), len(uhc_clean)],
    "Countries": [life_exp_clean["Country"].nunique(), mm_clean["Country"].nunique(), 
                  u5_clean["Country"].nunique(), uhc_clean["Country"].nunique()],
    "Year Range": [
        f"{life_exp_clean['Year'].min():.0f}-{life_exp_clean['Year'].max():.0f}",
        f"{mm_clean['Year'].min():.0f}-{mm_clean['Year'].max():.0f}",
        f"{u5_clean['Year'].min():.0f}-{u5_clean['Year'].max():.0f}",
        f"{uhc_clean['Year'].min():.0f}-{uhc_clean['Year'].max():.0f}"
    ]
}

summary_df = pd.DataFrame(summary)
print("📊 Data Summary")
print("="*50)
summary_df

# %% [markdown]
# ## 10. Export Data to CSV

# %%
# Export cleaned datasets to CSV files
life_exp_clean.to_csv("life_expectancy_data.csv", index=False)
mm_clean.to_csv("maternal_mortality_data.csv", index=False)
u5_clean.to_csv("under5_mortality_data.csv", index=False)
uhc_clean.to_csv("uhc_index_data.csv", index=False)

print("✅ Data exported successfully!")
print("- life_expectancy_data.csv")
print("- maternal_mortality_data.csv")
print("- under5_mortality_data.csv")
print("- uhc_index_data.csv")
